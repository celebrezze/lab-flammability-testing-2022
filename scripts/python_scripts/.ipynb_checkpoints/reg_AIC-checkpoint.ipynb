# %%
# Kristina Fauss
# April 19, 2024
# model selection by AIC testing all 1st order interactions

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import statsmodels.formula.api as smf

from ols_mixedef_custom import *

# %%
fp = '/Users/kristinafauss/BackupToBox/Git/lab-flammability-testing-2022/data/processed-data/main_dataset.csv'

flamog = pd.read_csv(fp)

# drop na's for flam metrics
print(len(flamog))
for col in ['fh', 'fd', 'pfg', 'temp_change', 'heat_flux_change']:
    flamog.dropna(subset=col, inplace=True)
print(len(flamog))

flamog['plant_id']=[str(a)+'_'+str(b) for a,b in zip(flamog['plant'], flamog['species'])]

# report
print(flamog.columns)
flamog.head()
# Out:
# 172
# 171
# Index(['Unnamed: 0', 'species', 'plant', 'date', 'total_branch_mass',
#        'total_leaf_mass', 'stem_mass_ratio', 'leaf_mass_ratio', 'leaf_lfm',
#        'thickness', 'leaf_wet_mass', 'leaf_dry_mass', 'stem_lfm', 'stem_width',
#        'stem_wet_mass', 'stem_dry_mass', 'stem_sav', 'lfm', 'leaf_dmc',
#        'stem_dmc', 'dmc', 'leaf_area', 'leaf_sav', 'LMA', 'SLA', 'rep',
#        'branch_length', 'branch_width', 'branch_height', 'sample_wt',
#        'no_branches', 'mpa', 'notes_on_plant_char', 'start_time',
#        'ambient_temp', 'ambient_humidity', 'pre_ignition_glow',
#        'first_glow_time', 'ignition', 'primary_ignition',
#        'primary_time_of_flame_end', 'secondary_ignition',
#        'secondary_time_of_flame_end', 'third_ignition',
#        'third_time_of_ignition_flame_end', 'time_fh', 'fh', 'time_of_glow_end',
#        'end_time', 'thermocoupler_height', 'hotplate_height',
#        'notes_on_flam_data', 'fd', 'tti', 'pfg', 'max_temp',
#        'time_at_max_temp', 'max_temp_sensor', 'start_temp',
#        'start_temp_sensor', 'stable_avg_temp', 'temp_change', 'avg_temp_ch3',
#        'max_heat_flux_loessCH7', 'time_at_max_heat_flux_loessCH7',
#        'max_heat_flux_loessCH8', 'time_at_max_heat_flux_loessCH8',
#        'avg_heat_flux_stableCH7', 'avg_heat_flux_stableCH8',
#        'heat_flux_change', 'prop_ig', 'wet_mass', 'dry_mass', 'gdw_gfw',
#        'dw_flam_sample', 'ww_flam_sample', 'branch_volume', 'branching',
#        'sample_density', 'dw_sppdev', 'plant_id'],
#       dtype='object')
#    Unnamed: 0 species  plant        date  total_branch_mass  total_leaf_mass  \
# 0           1  ARCDEN      1  2022-08-10             20.347           19.505
# 1           2  ARCDEN      1  2022-08-10             20.347           19.505
# 2           3  ARCDEN      1  2022-08-10             20.347           19.505
# 3           4  ARCDEN      1  2022-08-10             20.347           19.505
# 4           5  ARCDEN      1  2022-08-10             20.347           19.505
#
#    stem_mass_ratio  leaf_mass_ratio   leaf_lfm  thickness  ...  wet_mass  \
# 0         0.510564         0.489436  251.06912      0.514  ...     1.151
# 1         0.510564         0.489436  251.06912      0.514  ...     1.151
# 2         0.510564         0.489436  251.06912      0.514  ...     1.151
# 3         0.510564         0.489436  251.06912      0.514  ...     1.151
# 4         0.510564         0.489436  251.06912      0.514  ...     1.151
#
#    dry_mass   gdw_gfw  dw_flam_sample  ww_flam_sample  branch_volume  \
# 0    0.3683  0.242414        1.291195        4.035205        1082.04
# 1    0.3683  0.242414        1.429372        4.467028        1370.20
# 2    0.3683  0.242414        1.283923        4.012477         682.04
# 3    0.3683  0.242414        1.283923        4.012477        1262.25
# 4    0.3683  0.242414        0.811215        2.535185         819.00
#
#    branching  sample_density  dw_sppdev  plant_id
# 0   0.416667        0.004923   0.923122  1_ARCDEN
# 1   0.322581        0.004303   1.348152  1_ARCDEN
# 2   0.294118        0.007766   0.900752  1_ARCDEN
# 3   0.466667        0.004196   0.900752  1_ARCDEN
# 4   0.500000        0.004086  -0.553297  1_ARCDEN
#
# [5 rows x 81 columns]

# %%
model = smf.mixedlm("fh ~ total_branch_mass + species", data=flamog, groups=flamog["plant_id"])
results = model.fit(reml=False)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   fh
# No. Observations:    171       Method:               ML
# No. Groups:          58        Scale:                51.4006
# Min. group size:     1         Log-Likelihood:       -610.5181
# Max. group size:     11        Converged:            Yes
# Mean group size:     2.9
# --------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# --------------------------------------------------------------
# Intercept           1.807    8.316  0.217 0.828 -14.492 18.106
# species[T.ARTCAL]  -1.429    5.410 -0.264 0.792 -12.032  9.174
# species[T.CEAGRI]   6.016    5.222  1.152 0.249  -4.219 16.250
# species[T.ERIKAR] -12.658    5.016 -2.524 0.012 -22.489 -2.828
# species[T.HETARB]  11.932    5.969  1.999 0.046   0.234 23.630
# species[T.MALLAU]  -2.647    5.945 -0.445 0.656 -14.299  9.006
# species[T.SALAPI]   0.198    5.375  0.037 0.971 -10.336 10.732
# species[T.SALLEU]  -2.810    5.085 -0.553 0.581 -12.777  7.157
# total_branch_mass   1.146    0.360  3.181 0.001   0.440  1.852
# Group Var          38.508    2.421
# ==============================================================
#
# """

# %%
results.aic
# Out:
# 1243.0361180203022

# %% [markdown]
# # Examine Correlation & Structure in Num. Var's

# %%
cols_num_use = ['lfm', 'LMA', 'sample_wt', 'leaf_mass_ratio', 'branching', 'mpa', 'start_temp', 'dmc', 'branch_volume', 'stem_sav', 'leaf_sav', 'thickness']

corrplot(flamog, cols_num_use)

# %%
# PCAplot(flamog, cols_num_use)

# %% [markdown]
# # Modeling Preprocessing

# %%
# scale and center
cols_all = ['fh', 'fd', 'temp_change', 'heat_flux_change'] + cols_num_use
flam = scale_and_center(flamog, cols_all, cols_no_change=['plant_id', 'species', 'ignition'])

# declare as factors
flam['species'] = pd.Categorical(flam['species'])
flam['plant_id'] = pd.Categorical(flam['plant_id'])
flam['ignition'] = pd.Categorical(flam['ignition'])

# drop na's
print(len(flam))
cols_all_dpna = cols_all + ['plant_id', 'species', 'ignition']
flam.dropna(subset=cols_all_dpna, inplace=True)
print(len(flam))

# declare all possible IV cols to model
cols_use = cols_num_use + ['species']
print(cols_use)
# Out:
# 171
# 166
# ['lfm', 'LMA', 'sample_wt', 'leaf_mass_ratio', 'branching', 'mpa', 'start_temp', 'dmc', 'branch_volume', 'stem_sav', 'leaf_sav', 'thickness', 'species']

# %% [markdown]
# # Run Model Selector
#
# ### NOTE: Random effect is simply `plant_id`
# - NO nested effects
# - NO `species'
#
# #### It was not possible to test all combinations. Therefore, only combinations of significnt interaction terms and all singletons will be tested.

# %%
maxnumsingle = 7
minnumsingle = 1

# %% [markdown]
# # Flame Height

# %%
# REDUCE INTERACTIONS TO TEST

Y_VAR = 'fh'

# singletons: y = b + mx
compare_predictors_mixedeff(flam, cols_num_use, yvar=Y_VAR)

print('\n\n')

# singleton interactions: y = b + m1x1 + m2x2 + m3x1x2
sig_interactions = compare_predictors_interaction_singletons(flam,cols_use, y=Y_VAR, thresh=0.05, probs = ['fh ~ LMA*species'], printsumm=0)

print('\n\n')

# # try all 2-way interactions in 1 model
# form_all_int = formula_all_2way_interactions(cols_use, y='fh', report=0)
# model = smf.mixedlm(form_all_int, data=flam, groups=flam["plant_id"])
# result = model.fit(reml=False)
# # print only significant results
# significant_results = result.summary().tables[1].loc[result.pvalues < 0.05]
# print(significant_results)

print('\n\n')

# generate list of known interactions

sig_interactions_tuples = [tuple(x.split('*')) for x in sig_interactions]
for pair in sig_interactions_tuples:
    print(pair)
# Out:
#                cols         pvals     coefs  significant
# 2         sample_wt  2.290442e-17  0.531690         True
# 9          stem_sav  8.211280e-11 -0.576347         True
# 1               LMA  1.686945e-06  0.448328         True
# 8     branch_volume  1.785638e-06  0.328704         True
# 3   leaf_mass_ratio  1.627335e-05 -0.473655         True
# 4         branching  2.782677e-05  0.276897         True
# 0               lfm  1.956642e-04 -0.386256         True
# 7               dmc  1.914826e-03  0.275048         True
# 10         leaf_sav  5.369394e-03 -0.305540         True
# 5               mpa  2.542692e-01  0.088750        False
# 6        start_temp  3.136141e-01  0.077621        False
# 11        thickness  3.205268e-01  0.115109        False
#
#
#
# fh ~ lfm*LMA
# fh ~ lfm*sample_wt
# fh ~ lfm*leaf_mass_ratio
# fh ~ lfm*branching
# fh ~ lfm*mpa
# fh ~ lfm*start_temp
# fh ~ lfm*dmc
# fh ~ lfm*branch_volume
# fh ~ lfm*stem_sav
# fh ~ lfm*leaf_sav
# fh ~ lfm*thickness
# fh ~ lfm*species
# fh ~ LMA*sample_wt
# fh ~ LMA*leaf_mass_ratio
# fh ~ LMA*branching
# fh ~ LMA*mpa
# fh ~ LMA*start_temp
# fh ~ LMA*dmc
# fh ~ LMA*branch_volume
# fh ~ LMA*stem_sav
# fh ~ LMA*leaf_sav
# fh ~ LMA*thickness
# fh ~ LMA*species
# fh ~ sample_wt*leaf_mass_ratio
# fh ~ sample_wt*branching
# fh ~ sample_wt*mpa
# fh ~ sample_wt*start_temp
# fh ~ sample_wt*dmc
# fh ~ sample_wt*branch_volume
# fh ~ sample_wt*stem_sav
# fh ~ sample_wt*leaf_sav
# fh ~ sample_wt*thickness
# fh ~ sample_wt*species
# fh ~ leaf_mass_ratio*branching
# fh ~ leaf_mass_ratio*mpa
# fh ~ leaf_mass_ratio*start_temp
# fh ~ leaf_mass_ratio*dmc
# fh ~ leaf_mass_ratio*branch_volume
# fh ~ leaf_mass_ratio*stem_sav
# fh ~ leaf_mass_ratio*leaf_sav
# fh ~ leaf_mass_ratio*thickness
# fh ~ leaf_mass_ratio*species
# fh ~ branching*mpa
# fh ~ branching*start_temp
# fh ~ branching*dmc
# fh ~ branching*branch_volume
# fh ~ branching*stem_sav
# fh ~ branching*leaf_sav
# fh ~ branching*thickness
# fh ~ branching*species
# fh ~ mpa*start_temp
# fh ~ mpa*dmc
# fh ~ mpa*branch_volume
# fh ~ mpa*stem_sav
# fh ~ mpa*leaf_sav
# fh ~ mpa*thickness
# fh ~ mpa*species
# fh ~ start_temp*dmc
# fh ~ start_temp*branch_volume
# fh ~ start_temp*stem_sav
# fh ~ start_temp*leaf_sav
# fh ~ start_temp*thickness
# fh ~ start_temp*species
# fh ~ dmc*branch_volume
# fh ~ dmc*stem_sav
# fh ~ dmc*leaf_sav
# fh ~ dmc*thickness
# fh ~ dmc*species
# fh ~ branch_volume*stem_sav
# fh ~ branch_volume*leaf_sav
# fh ~ branch_volume*thickness
# fh ~ branch_volume*species
# fh ~ stem_sav*leaf_sav
# fh ~ stem_sav*thickness
# fh ~ stem_sav*species
# fh ~ leaf_sav*thickness
# fh ~ leaf_sav*species
# fh ~ thickness*species
# 13 13 {'lfm', 'branching', 'branch_volume', 'stem_sav', 'mpa', 'start_temp', 'thickness', 'dmc', 'leaf_mass_ratio', 'sample_wt', 'species', 'leaf_sav', 'LMA'}
#
#
#
#
#
#
# ('lfm', 'sample_wt')
# ('lfm', 'dmc')
# ('lfm', 'branch_volume')
# ('lfm', 'leaf_sav')
# ('lfm', 'thickness')
# ('lfm', 'species')
# ('LMA', 'stem_sav')
# ('sample_wt', 'species')
# ('leaf_mass_ratio', 'dmc')
# ('leaf_mass_ratio', 'leaf_sav')
# ('leaf_mass_ratio', 'thickness')
# ('leaf_mass_ratio', 'species')
# ('branching', 'leaf_sav')
# ('branching', 'species')
# ('mpa', 'branch_volume')
# ('mpa', 'species')
# ('start_temp', 'dmc')
# ('start_temp', 'species')
# ('dmc', 'stem_sav')
# ('dmc', 'leaf_sav')
# ('dmc', 'thickness')
# ('dmc', 'species')
# ('branch_volume', 'leaf_sav')
# ('branch_volume', 'thickness')
# ('branch_volume', 'species')
# ('stem_sav', 'species')
# ('leaf_sav', 'species')
# ('thickness', 'species')

# %%
# generate list of formulas

df = flam
cols = cols_use
int_tuple_list = sig_interactions_tuples
dv = Y_VAR


formulas = []
cols_used = []

# iterate over possible interactions
for int_tup in int_tuple_list:
    
    # create a copy of singletons list
    cols_wkg = cols.copy()
    # isolate terms in interaction
    x1,x2 = int_tup
    # drop those terms from singletons list
    cols_wkg.remove(x1)
    cols_wkg.remove(x2)
    
    # add the 1st formula - just the interaction term y ~ x1 * x2
    formulas.append(dv+' ~ '+x1+'*'+x2)
    colsi = [x1,x2]

    # generate list of all possible combos of singletons, from 1 to as many as there are
    singles_combos = [list(combinations(cols_wkg, n)) for n in range(minnumsingle, maxnumsingle+1)]

    # iterate over combo set (ie 1 poss singleton, 2 poss singletons, ... etc)
    for comboset in singles_combos:
        # for each combo in the combo set
        for combo in comboset:
            # generate formula
            form = dv+' ~ '+x1+'*'+x2
            for single in combo:
                form+=' + '+single
                colsi.append(single)
            formulas.append(form)
            cols_used.append([colsi])

print(len(formulas))

# AIC ITERATION
resdf_fh, num_top_models = AICscore_from_all_pos_2way_interactions(df, formulas, report=0)

# report
for idx,row in resdf_fh[0:num_top_models].iterrows():
    formula = row.Formula
    print(formula)
for idx,row in resdf_fh[0:num_top_models].iterrows():
    formula = row.Formula
    model = smf.ols(formula, data=df)
    results = model.fit()
    print(results.summary())
    plot_ols_coefficients(results)
    plt.show();
    # if 'species' in cols:
    #     cols.remove('species')
    # plot_resid(df, cols, results)
# Out:
# 336
# 336 336
# fh ~ branching*species + sample_wt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     fh   R-squared:                       0.663
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     18.30
# Date:                Tue, 23 Apr 2024   Prob (F-statistic):           1.44e-27
# Time:                        18:59:56   Log-Likelihood:                -142.36
# No. Observations:                 166   AIC:                             318.7
# Df Residuals:                     149   BIC:                             371.6
# Df Model:                          16
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.6697      0.362      1.850      0.066      -0.046       1.385
# species[T.ARTCAL]              -0.5568      0.399     -1.394      0.165      -1.346       0.232
# species[T.CEAGRI]              -0.0802      0.402     -0.199      0.842      -0.875       0.715
# species[T.ERIKAR]              -0.9955      0.440     -2.264      0.025      -1.864      -0.127
# species[T.HETARB]              -0.7456      0.590     -1.263      0.209      -1.912       0.421
# species[T.MALLAU]              -0.7259      0.416     -1.747      0.083      -1.547       0.095
# species[T.SALAPI]              -0.3308      0.427     -0.776      0.439      -1.174       0.512
# species[T.SALLEU]              -0.6638      0.377     -1.762      0.080      -1.408       0.081
# branching                      -0.5281      0.278     -1.900      0.059      -1.077       0.021
# branching:species[T.ARTCAL]     0.7981      0.313      2.551      0.012       0.180       1.416
# branching:species[T.CEAGRI]     0.6371      0.307      2.075      0.040       0.030       1.244
# branching:species[T.ERIKAR]     1.0316      0.419      2.462      0.015       0.204       1.859
# branching:species[T.HETARB]    -2.4134      1.107     -2.180      0.031      -4.601      -0.226
# branching:species[T.MALLAU]     0.9481      0.325      2.917      0.004       0.306       1.590
# branching:species[T.SALAPI]     0.7520      0.385      1.952      0.053      -0.009       1.513
# branching:species[T.SALLEU]     0.5944      0.301      1.974      0.050      -0.001       1.189
# sample_wt                       0.5015      0.081      6.226      0.000       0.342       0.661
# ==============================================================================
# Omnibus:                       13.268   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               26.857
# Skew:                           0.321   Prob(JB):                     1.47e-06
# Kurtosis:                       4.863   Cond. No.                         32.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Flame Duration

# %%
# REDUCE INTERACTIONS TO TEST

Y_VAR = 'fd'

# singletons: y = b + mx
compare_predictors_mixedeff(flam, cols_num_use, yvar=Y_VAR)

print('\n\n')

# singleton interactions: y = b + m1x1 + m2x2 + m3x1x2
sig_interactions = compare_predictors_interaction_singletons(flam,cols_use, y=Y_VAR, thresh=0.05, probs = [], printsumm=0)

print('\n\n')

# # try all 2-way interactions in 1 model
# form_all_int = formula_all_2way_interactions(cols_use, y='fh', report=0)
# model = smf.mixedlm(form_all_int, data=flam, groups=flam["plant_id"])
# result = model.fit(reml=False)
# # print only significant results
# significant_results = result.summary().tables[1].loc[result.pvalues < 0.05]
# print(significant_results)

print('\n\n')

# generate list of known interactions

sig_interactions_tuples = [tuple(x.split('*')) for x in sig_interactions]
for pair in sig_interactions_tuples:
    print(pair)
# Out:
#                cols         pvals     coefs  significant
# 2         sample_wt  2.181882e-11  0.499795         True
# 8     branch_volume  1.223520e-06  0.372319         True
# 7               dmc  2.344202e-06  0.390794         True
# 9          stem_sav  2.513616e-06 -0.385912         True
# 0               lfm  6.575573e-05 -0.348868         True
# 1               LMA  7.605417e-05  0.362449         True
# 3   leaf_mass_ratio  4.525313e-04 -0.380075         True
# 10         leaf_sav  7.496719e-03 -0.272524         True
# 4         branching  1.364565e-02  0.206268         True
# 11        thickness  6.348566e-02  0.204278        False
# 6        start_temp  3.760549e-01 -0.077204        False
# 5               mpa  5.031638e-01 -0.064662        False
#
#
#
# fd ~ lfm*LMA
# fd ~ lfm*sample_wt
# fd ~ lfm*leaf_mass_ratio
# fd ~ lfm*branching
# fd ~ lfm*mpa
# fd ~ lfm*start_temp
# fd ~ lfm*dmc
# fd ~ lfm*branch_volume
# fd ~ lfm*stem_sav
# fd ~ lfm*leaf_sav
# fd ~ lfm*thickness
# fd ~ lfm*species
# fd ~ LMA*sample_wt
# fd ~ LMA*leaf_mass_ratio
# fd ~ LMA*branching
# fd ~ LMA*mpa
# fd ~ LMA*start_temp
# fd ~ LMA*dmc
# fd ~ LMA*branch_volume
# fd ~ LMA*stem_sav
# fd ~ LMA*leaf_sav
# fd ~ LMA*thickness
# fd ~ LMA*species
# fd ~ sample_wt*leaf_mass_ratio
# fd ~ sample_wt*branching
# fd ~ sample_wt*mpa
# fd ~ sample_wt*start_temp
# fd ~ sample_wt*dmc
# fd ~ sample_wt*branch_volume
# fd ~ sample_wt*stem_sav
# fd ~ sample_wt*leaf_sav
# fd ~ sample_wt*thickness
# fd ~ sample_wt*species
# fd ~ leaf_mass_ratio*branching
# fd ~ leaf_mass_ratio*mpa
# fd ~ leaf_mass_ratio*start_temp
# fd ~ leaf_mass_ratio*dmc
# fd ~ leaf_mass_ratio*branch_volume
# fd ~ leaf_mass_ratio*stem_sav
# fd ~ leaf_mass_ratio*leaf_sav
# fd ~ leaf_mass_ratio*thickness
# fd ~ leaf_mass_ratio*species
# fd ~ branching*mpa
# fd ~ branching*start_temp
# fd ~ branching*dmc
# fd ~ branching*branch_volume
# fd ~ branching*stem_sav
# fd ~ branching*leaf_sav
# fd ~ branching*thickness
# fd ~ branching*species
# fd ~ mpa*start_temp
# fd ~ mpa*dmc
# fd ~ mpa*branch_volume
# fd ~ mpa*stem_sav
# fd ~ mpa*leaf_sav
# fd ~ mpa*thickness
# fd ~ mpa*species
# fd ~ start_temp*dmc
# fd ~ start_temp*branch_volume
# fd ~ start_temp*stem_sav
# fd ~ start_temp*leaf_sav
# fd ~ start_temp*thickness
# fd ~ start_temp*species
# fd ~ dmc*branch_volume
# fd ~ dmc*stem_sav
# fd ~ dmc*leaf_sav
# fd ~ dmc*thickness
# fd ~ dmc*species
# fd ~ branch_volume*stem_sav
# fd ~ branch_volume*leaf_sav
# fd ~ branch_volume*thickness
# fd ~ branch_volume*species
# fd ~ stem_sav*leaf_sav
# fd ~ stem_sav*thickness
# fd ~ stem_sav*species
# fd ~ leaf_sav*thickness
# fd ~ leaf_sav*species
# fd ~ thickness*species
# 13 13 {'lfm', 'branching', 'stem_sav', 'mpa', 'branch_volume', 'start_temp', 'thickness', 'dmc', 'leaf_mass_ratio', 'sample_wt', 'species', 'leaf_sav', 'LMA'}
#
#
#
#
#
#
# ('lfm', 'sample_wt')
# ('lfm', 'stem_sav')
# ('LMA', 'leaf_sav')
# ('LMA', 'thickness')
# ('LMA', 'species')
# ('sample_wt', 'dmc')
# ('sample_wt', 'leaf_sav')
# ('sample_wt', 'species')
# ('leaf_mass_ratio', 'dmc')
# ('branching', 'stem_sav')
# ('mpa', 'branch_volume')
# ('start_temp', 'species')
# ('dmc', 'branch_volume')
# ('thickness', 'species')

# %%
# generate list of formulas

df = flam
cols = cols_use
int_tuple_list = sig_interactions_tuples
dv = Y_VAR


formulas = []
cols_used = []

# iterate over possible interactions
for int_tup in int_tuple_list:
    
    # create a copy of singletons list
    cols_wkg = cols.copy()
    # isolate terms in interaction
    x1,x2 = int_tup
    # drop those terms from singletons list
    cols_wkg.remove(x1)
    cols_wkg.remove(x2)
    
    # add the 1st formula - just the interaction term y ~ x1 * x2
    formulas.append(dv+' ~ '+x1+'*'+x2)
    colsi = [x1,x2]

    # generate list of all possible combos of singletons, from 1 to as many as there are
    singles_combos = [list(combinations(cols_wkg, n)) for n in range(minnumsingle, maxnumsingle+1)]

    # iterate over combo set (ie 1 poss singleton, 2 poss singletons, ... etc)
    for comboset in singles_combos:
        # for each combo in the combo set
        for combo in comboset:
            # generate formula
            form = dv+' ~ '+x1+'*'+x2
            for single in combo:
                form+=' + '+single
                colsi.append(single)
            formulas.append(form)
            cols_used.append([colsi])

print(len(formulas))

# AIC ITERATION
resdf_fd, num_top_models = AICscore_from_all_pos_2way_interactions(df, formulas, report=0)

# report
for idx,row in resdf_fd[0:num_top_models].iterrows():
    formula = row.Formula
    print(formula)
for idx,row in resdf_fd[0:num_top_models].iterrows():
    formula = row.Formula
    model = smf.ols(formula, data=df)
    results = model.fit()
    print(results.summary())
    plot_ols_coefficients(results)
    plt.show();
    # if 'species' in cols:
    #     cols.remove('species')
    # plot_resid(df, cols, results)

# %% [markdown]
# # Temp Change

# %%
# REDUCE INTERACTIONS TO TEST

Y_VAR = 'temp_change'

# singletons: y = b + mx
compare_predictors_mixedeff(flam, cols_num_use, yvar=Y_VAR)

print('\n\n')

# singleton interactions: y = b + m1x1 + m2x2 + m3x1x2
sig_interactions = compare_predictors_interaction_singletons(flam,cols_use, y=Y_VAR, thresh=0.05, 
                                                             probs = ['temp_change ~ leaf_sav*thickness'], printsumm=0)

print('\n\n')

# # try all 2-way interactions in 1 model
# form_all_int = formula_all_2way_interactions(cols_use, y='fh', report=0)
# model = smf.mixedlm(form_all_int, data=flam, groups=flam["plant_id"])
# result = model.fit(reml=False)
# # print only significant results
# significant_results = result.summary().tables[1].loc[result.pvalues < 0.05]
# print(significant_results)

print('\n\n')

# generate list of known interactions

sig_interactions_tuples = [tuple(x.split('*')) for x in sig_interactions]
for pair in sig_interactions_tuples:
    print(pair)
# Out:
#                cols     pvals     coefs  significant
# 6        start_temp  0.000017 -0.320890         True
# 1               LMA  0.000019  0.534923         True
# 2         sample_wt  0.000258  0.282132         True
# 4         branching  0.002838  0.196010         True
# 0               lfm  0.010824 -0.382844         True
# 10         leaf_sav  0.020611 -0.333811         True
# 9          stem_sav  0.022272 -0.380000         True
# 5               mpa  0.036702  0.162373         True
# 7               dmc  0.049687  0.193818         True
# 8     branch_volume  0.050270  0.146199        False
# 11        thickness  0.115967  0.208315        False
# 3   leaf_mass_ratio  0.138911 -0.208767        False
#
#
#
# temp_change ~ lfm*LMA
# temp_change ~ lfm*sample_wt
# temp_change ~ lfm*leaf_mass_ratio
# temp_change ~ lfm*branching
# temp_change ~ lfm*mpa
# temp_change ~ lfm*start_temp
# temp_change ~ lfm*dmc
# temp_change ~ lfm*branch_volume
# temp_change ~ lfm*stem_sav
# temp_change ~ lfm*leaf_sav
# temp_change ~ lfm*thickness
# temp_change ~ lfm*species
# temp_change ~ LMA*sample_wt
# temp_change ~ LMA*leaf_mass_ratio
# temp_change ~ LMA*branching
# temp_change ~ LMA*mpa
# temp_change ~ LMA*start_temp
# temp_change ~ LMA*dmc
# temp_change ~ LMA*branch_volume
# temp_change ~ LMA*stem_sav
# temp_change ~ LMA*leaf_sav
# temp_change ~ LMA*thickness
# temp_change ~ LMA*species
# temp_change ~ sample_wt*leaf_mass_ratio
# temp_change ~ sample_wt*branching
# temp_change ~ sample_wt*mpa
# temp_change ~ sample_wt*start_temp
# temp_change ~ sample_wt*dmc
# temp_change ~ sample_wt*branch_volume
# temp_change ~ sample_wt*stem_sav
# temp_change ~ sample_wt*leaf_sav
# temp_change ~ sample_wt*thickness
# temp_change ~ sample_wt*species
# temp_change ~ leaf_mass_ratio*branching
# temp_change ~ leaf_mass_ratio*mpa
# temp_change ~ leaf_mass_ratio*start_temp
# temp_change ~ leaf_mass_ratio*dmc
# temp_change ~ leaf_mass_ratio*branch_volume
# temp_change ~ leaf_mass_ratio*stem_sav
# temp_change ~ leaf_mass_ratio*leaf_sav
# temp_change ~ leaf_mass_ratio*thickness
# temp_change ~ leaf_mass_ratio*species
# temp_change ~ branching*mpa
# temp_change ~ branching*start_temp
# temp_change ~ branching*dmc
# temp_change ~ branching*branch_volume
# temp_change ~ branching*stem_sav
# temp_change ~ branching*leaf_sav
# temp_change ~ branching*thickness
# temp_change ~ branching*species
# temp_change ~ mpa*start_temp
# temp_change ~ mpa*dmc
# temp_change ~ mpa*branch_volume
# temp_change ~ mpa*stem_sav
# temp_change ~ mpa*leaf_sav
# temp_change ~ mpa*thickness
# temp_change ~ mpa*species
# temp_change ~ start_temp*dmc
# temp_change ~ start_temp*branch_volume
# temp_change ~ start_temp*stem_sav
# temp_change ~ start_temp*leaf_sav
# temp_change ~ start_temp*thickness
# temp_change ~ start_temp*species
# temp_change ~ dmc*branch_volume
# temp_change ~ dmc*stem_sav
# temp_change ~ dmc*leaf_sav
# temp_change ~ dmc*thickness
# temp_change ~ dmc*species
# temp_change ~ branch_volume*stem_sav
# temp_change ~ branch_volume*leaf_sav
# temp_change ~ branch_volume*thickness
# temp_change ~ branch_volume*species
# temp_change ~ stem_sav*leaf_sav
# temp_change ~ stem_sav*thickness
# temp_change ~ stem_sav*species
# temp_change ~ leaf_sav*thickness
# temp_change ~ leaf_sav*species
# temp_change ~ thickness*species
# 13 13 {'lfm', 'branching', 'branch_volume', 'start_temp', 'mpa', 'stem_sav', 'thickness', 'dmc', 'leaf_mass_ratio', 'sample_wt', 'species', 'leaf_sav', 'LMA'}
#
#
#
#
#
#
# ('lfm', 'LMA')
# ('lfm', 'sample_wt')
# ('lfm', 'start_temp')
# ('lfm', 'leaf_sav')
# ('lfm', 'species')
# ('LMA', 'species')
# ('sample_wt', 'start_temp')
# ('sample_wt', 'branch_volume')
# ('sample_wt', 'species')
# ('leaf_mass_ratio', 'species')
# ('branching', 'start_temp')
# ('branching', 'species')
# ('mpa', 'start_temp')
# ('mpa', 'species')
# ('start_temp', 'branch_volume')
# ('start_temp', 'leaf_sav')
# ('start_temp', 'thickness')
# ('start_temp', 'species')
# ('dmc', 'species')
# ('branch_volume', 'leaf_sav')
# ('branch_volume', 'thickness')
# ('branch_volume', 'species')
# ('stem_sav', 'species')
# ('leaf_sav', 'species')
# ('thickness', 'species')

# %%
# generate list of formulas

df = flam
cols = cols_use
int_tuple_list = sig_interactions_tuples
dv = Y_VAR


formulas = []
cols_used = []

# iterate over possible interactions
for int_tup in int_tuple_list:
    
    # create a copy of singletons list
    cols_wkg = cols.copy()
    # isolate terms in interaction
    x1,x2 = int_tup
    # drop those terms from singletons list
    cols_wkg.remove(x1)
    cols_wkg.remove(x2)
    
    # add the 1st formula - just the interaction term y ~ x1 * x2
    formulas.append(dv+' ~ '+x1+'*'+x2)
    colsi = [x1,x2]

    # generate list of all possible combos of singletons, from 1 to as many as there are
    singles_combos = [list(combinations(cols_wkg, n)) for n in range(minnumsingle, maxnumsingle+1)]

    # iterate over combo set (ie 1 poss singleton, 2 poss singletons, ... etc)
    for comboset in singles_combos:
        # for each combo in the combo set
        for combo in comboset:
            # generate formula
            form = dv+' ~ '+x1+'*'+x2
            for single in combo:
                form+=' + '+single
                colsi.append(single)
            formulas.append(form)
            cols_used.append([colsi])

print(len(formulas))

# AIC ITERATION
resdf_tc, num_top_models = AICscore_from_all_pos_2way_interactions(df, formulas, report=0)

# report
for idx,row in resdf_tc[0:num_top_models].iterrows():
    formula = row.Formula
    print(formula)
for idx,row in resdf_tc[0:num_top_models].iterrows():
    formula = row.Formula
    model = smf.ols(formula, data=df)
    results = model.fit()
    print(results.summary())
    plot_ols_coefficients(results)
    plt.show();
    # if 'species' in cols:
    #     cols.remove('species')
    # plot_resid(df, cols, results)

# %% [markdown]
# # Heat Flux Change

# %%
# REDUCE INTERACTIONS TO TEST

Y_VAR = 'heat_flux_change'

# singletons: y = b + mx
compare_predictors_mixedeff(flam, cols_num_use, yvar=Y_VAR)

print('\n\n')

# singleton interactions: y = b + m1x1 + m2x2 + m3x1x2
sig_interactions = compare_predictors_interaction_singletons(flam,cols_use, y=Y_VAR, thresh=0.05, probs = [], printsumm=0)

print('\n\n')

# # try all 2-way interactions in 1 model
# form_all_int = formula_all_2way_interactions(cols_use, y='fh', report=0)
# model = smf.mixedlm(form_all_int, data=flam, groups=flam["plant_id"])
# result = model.fit(reml=False)
# # print only significant results
# significant_results = result.summary().tables[1].loc[result.pvalues < 0.05]
# print(significant_results)

print('\n\n')

# generate list of known interactions

sig_interactions_tuples = [tuple(x.split('*')) for x in sig_interactions]
for pair in sig_interactions_tuples:
    print(pair)
# Out:
#                cols         pvals     coefs  significant
# 2         sample_wt  4.833183e-25  0.670656         True
# 8     branch_volume  2.758968e-09  0.438674         True
# 1               LMA  2.433891e-08  0.481080         True
# 9          stem_sav  8.420917e-05 -0.378518         True
# 3   leaf_mass_ratio  3.820173e-04 -0.404141         True
# 10         leaf_sav  8.635177e-04 -0.335408         True
# 0               lfm  5.211122e-03 -0.285119         True
# 7               dmc  1.135685e-02  0.240699         True
# 4         branching  1.403803e-02  0.194726         True
# 11        thickness  1.707630e-01  0.154728        False
# 6        start_temp  2.560324e-01  0.101154        False
# 5               mpa  8.944642e-01 -0.011634        False
#
#
#
# heat_flux_change ~ lfm*LMA
# heat_flux_change ~ lfm*sample_wt
# heat_flux_change ~ lfm*leaf_mass_ratio
# heat_flux_change ~ lfm*branching
# heat_flux_change ~ lfm*mpa
# heat_flux_change ~ lfm*start_temp
# heat_flux_change ~ lfm*dmc
# heat_flux_change ~ lfm*branch_volume
# heat_flux_change ~ lfm*stem_sav
# heat_flux_change ~ lfm*leaf_sav
# heat_flux_change ~ lfm*thickness
# heat_flux_change ~ lfm*species
# heat_flux_change ~ LMA*sample_wt
# heat_flux_change ~ LMA*leaf_mass_ratio
# heat_flux_change ~ LMA*branching
# heat_flux_change ~ LMA*mpa
# heat_flux_change ~ LMA*start_temp
# heat_flux_change ~ LMA*dmc
# heat_flux_change ~ LMA*branch_volume
# heat_flux_change ~ LMA*stem_sav
# heat_flux_change ~ LMA*leaf_sav
# heat_flux_change ~ LMA*thickness
# heat_flux_change ~ LMA*species
# heat_flux_change ~ sample_wt*leaf_mass_ratio
# heat_flux_change ~ sample_wt*branching
# heat_flux_change ~ sample_wt*mpa
# heat_flux_change ~ sample_wt*start_temp
# heat_flux_change ~ sample_wt*dmc
# heat_flux_change ~ sample_wt*branch_volume
# heat_flux_change ~ sample_wt*stem_sav
# heat_flux_change ~ sample_wt*leaf_sav
# heat_flux_change ~ sample_wt*thickness
# heat_flux_change ~ sample_wt*species
# heat_flux_change ~ leaf_mass_ratio*branching
# heat_flux_change ~ leaf_mass_ratio*mpa
# heat_flux_change ~ leaf_mass_ratio*start_temp
# heat_flux_change ~ leaf_mass_ratio*dmc
# heat_flux_change ~ leaf_mass_ratio*branch_volume
# heat_flux_change ~ leaf_mass_ratio*stem_sav
# heat_flux_change ~ leaf_mass_ratio*leaf_sav
# heat_flux_change ~ leaf_mass_ratio*thickness
# heat_flux_change ~ leaf_mass_ratio*species
# heat_flux_change ~ branching*mpa
# heat_flux_change ~ branching*start_temp
# heat_flux_change ~ branching*dmc
# heat_flux_change ~ branching*branch_volume
# heat_flux_change ~ branching*stem_sav
# heat_flux_change ~ branching*leaf_sav
# heat_flux_change ~ branching*thickness
# heat_flux_change ~ branching*species
# heat_flux_change ~ mpa*start_temp
# heat_flux_change ~ mpa*dmc
# heat_flux_change ~ mpa*branch_volume
# heat_flux_change ~ mpa*stem_sav
# heat_flux_change ~ mpa*leaf_sav
# heat_flux_change ~ mpa*thickness
# heat_flux_change ~ mpa*species
# heat_flux_change ~ start_temp*dmc
# heat_flux_change ~ start_temp*branch_volume
# heat_flux_change ~ start_temp*stem_sav
# heat_flux_change ~ start_temp*leaf_sav
# heat_flux_change ~ start_temp*thickness
# heat_flux_change ~ start_temp*species
# heat_flux_change ~ dmc*branch_volume
# heat_flux_change ~ dmc*stem_sav
# heat_flux_change ~ dmc*leaf_sav
# heat_flux_change ~ dmc*thickness
# heat_flux_change ~ dmc*species
# heat_flux_change ~ branch_volume*stem_sav
# heat_flux_change ~ branch_volume*leaf_sav
# heat_flux_change ~ branch_volume*thickness
# heat_flux_change ~ branch_volume*species
# heat_flux_change ~ stem_sav*leaf_sav
# heat_flux_change ~ stem_sav*thickness
# heat_flux_change ~ stem_sav*species
# heat_flux_change ~ leaf_sav*thickness
# heat_flux_change ~ leaf_sav*species
# heat_flux_change ~ thickness*species
# 13 10 {'lfm', 'branch_volume', 'stem_sav', 'start_temp', 'thickness', 'dmc', 'leaf_mass_ratio', 'sample_wt', 'species', 'LMA'}
#
#
#
#
#
#
# ('lfm', 'dmc')
# ('LMA', 'branch_volume')
# ('sample_wt', 'leaf_mass_ratio')
# ('sample_wt', 'dmc')
# ('sample_wt', 'stem_sav')
# ('leaf_mass_ratio', 'branch_volume')
# ('leaf_mass_ratio', 'stem_sav')
# ('leaf_mass_ratio', 'thickness')
# ('start_temp', 'species')
# ('dmc', 'branch_volume')
# ('dmc', 'stem_sav')
# ('dmc', 'thickness')
# ('dmc', 'species')

# %%
# generate list of formulas

df = flam
cols = cols_use
int_tuple_list = sig_interactions_tuples
dv = Y_VAR


formulas = []
cols_used = []

# iterate over possible interactions
for int_tup in int_tuple_list:
    
    # create a copy of singletons list
    cols_wkg = cols.copy()
    # isolate terms in interaction
    x1,x2 = int_tup
    # drop those terms from singletons list
    cols_wkg.remove(x1)
    cols_wkg.remove(x2)
    
    # add the 1st formula - just the interaction term y ~ x1 * x2
    formulas.append(dv+' ~ '+x1+'*'+x2)
    colsi = [x1,x2]

    # generate list of all possible combos of singletons, from 1 to as many as there are
    singles_combos = [list(combinations(cols_wkg, n)) for n in range(minnumsingle, maxnumsingle+1)]

    # iterate over combo set (ie 1 poss singleton, 2 poss singletons, ... etc)
    for comboset in singles_combos:
        # for each combo in the combo set
        for combo in comboset:
            # generate formula
            form = dv+' ~ '+x1+'*'+x2
            for single in combo:
                form+=' + '+single
                colsi.append(single)
            formulas.append(form)
            cols_used.append([colsi])

print(len(formulas))

# AIC ITERATION
resdf_hx, num_top_models = AICscore_from_all_pos_2way_interactions(df, formulas, report=0)

# report
for idx,row in resdf_hx[0:num_top_models].iterrows():
    formula = row.Formula
    print(formula)
for idx,row in resdf_hx[0:num_top_models].iterrows():
    formula = row.Formula
    model = smf.ols(formula, data=df)
    results = model.fit()
    print(results.summary())
    plot_ols_coefficients(results)
    plt.show();
    # if 'species' in cols:
    #     cols.remove('species')
    # plot_resid(df, cols, results)
