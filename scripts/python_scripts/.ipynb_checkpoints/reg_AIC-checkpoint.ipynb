# %%
# Kristina Fauss
# April 19, 2024
# model selection by AIC testing all 1st order interactions

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import statsmodels.formula.api as smf

from ols_mixedef_custom import *

# %%
fp = '/Users/kristinafauss/BackupToBox/Git/lab-flammability-testing-2022/data/processed-data/main_dataset.csv'

flamog = pd.read_csv(fp)

# drop na's for flam metrics
print(len(flamog))
for col in ['fh', 'fd', 'pfg', 'temp_change', 'heat_flux_change']:
    flamog.dropna(subset=col, inplace=True)
print(len(flamog))

flamog['plant_id']=[str(a)+'_'+str(b) for a,b in zip(flamog['plant'], flamog['species'])]

# report
print(flamog.columns)
flamog.head()
# Out:
# 172
# 171
# Index(['Unnamed: 0', 'species', 'plant', 'date', 'total_branch_mass',
#        'total_leaf_mass', 'stem_mass_ratio', 'leaf_mass_ratio', 'leaf_lfm',
#        'thickness', 'leaf_wet_mass', 'leaf_dry_mass', 'stem_lfm', 'stem_width',
#        'stem_wet_mass', 'stem_dry_mass', 'stem_sav', 'lfm', 'leaf_dmc',
#        'stem_dmc', 'dmc', 'leaf_area', 'leaf_sav', 'LMA', 'SLA', 'rep',
#        'branch_length', 'branch_width', 'branch_height', 'sample_wt',
#        'no_branches', 'mpa', 'notes_on_plant_char', 'start_time',
#        'ambient_temp', 'ambient_humidity', 'pre_ignition_glow',
#        'first_glow_time', 'ignition', 'primary_ignition',
#        'primary_time_of_flame_end', 'secondary_ignition',
#        'secondary_time_of_flame_end', 'third_ignition',
#        'third_time_of_ignition_flame_end', 'time_fh', 'fh', 'time_of_glow_end',
#        'end_time', 'thermocoupler_height', 'hotplate_height',
#        'notes_on_flam_data', 'fd', 'tti', 'pfg', 'max_temp',
#        'time_at_max_temp', 'max_temp_sensor', 'start_temp',
#        'start_temp_sensor', 'stable_avg_temp', 'temp_change', 'avg_temp_ch3',
#        'max_heat_flux_loessCH7', 'time_at_max_heat_flux_loessCH7',
#        'max_heat_flux_loessCH8', 'time_at_max_heat_flux_loessCH8',
#        'avg_heat_flux_stableCH7', 'avg_heat_flux_stableCH8',
#        'heat_flux_change', 'prop_ig', 'wet_mass', 'dry_mass', 'gdw_gfw',
#        'dw_flam_sample', 'ww_flam_sample', 'branch_volume', 'branching',
#        'sample_density', 'dw_sppdev', 'plant_id'],
#       dtype='object')
#    Unnamed: 0 species  plant        date  total_branch_mass  total_leaf_mass  \
# 0           1  ARCDEN      1  2022-08-10             20.347           19.505
# 1           2  ARCDEN      1  2022-08-10             20.347           19.505
# 2           3  ARCDEN      1  2022-08-10             20.347           19.505
# 3           4  ARCDEN      1  2022-08-10             20.347           19.505
# 4           5  ARCDEN      1  2022-08-10             20.347           19.505
#
#    stem_mass_ratio  leaf_mass_ratio   leaf_lfm  thickness  ...  wet_mass  \
# 0         0.510564         0.489436  251.06912      0.514  ...     1.151
# 1         0.510564         0.489436  251.06912      0.514  ...     1.151
# 2         0.510564         0.489436  251.06912      0.514  ...     1.151
# 3         0.510564         0.489436  251.06912      0.514  ...     1.151
# 4         0.510564         0.489436  251.06912      0.514  ...     1.151
#
#    dry_mass   gdw_gfw  dw_flam_sample  ww_flam_sample  branch_volume  \
# 0    0.3683  0.242414        1.291195        4.035205        1082.04
# 1    0.3683  0.242414        1.429372        4.467028        1370.20
# 2    0.3683  0.242414        1.283923        4.012477         682.04
# 3    0.3683  0.242414        1.283923        4.012477        1262.25
# 4    0.3683  0.242414        0.811215        2.535185         819.00
#
#    branching  sample_density  dw_sppdev  plant_id
# 0   0.416667        0.004923   0.923122  1_ARCDEN
# 1   0.322581        0.004303   1.348152  1_ARCDEN
# 2   0.294118        0.007766   0.900752  1_ARCDEN
# 3   0.466667        0.004196   0.900752  1_ARCDEN
# 4   0.500000        0.004086  -0.553297  1_ARCDEN
#
# [5 rows x 81 columns]

# %%
model = smf.mixedlm("fh ~ total_branch_mass + species", data=flamog, groups=flamog["plant_id"])
results = model.fit(reml=False)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   fh
# No. Observations:    171       Method:               ML
# No. Groups:          58        Scale:                51.4006
# Min. group size:     1         Log-Likelihood:       -610.5181
# Max. group size:     11        Converged:            Yes
# Mean group size:     2.9
# --------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# --------------------------------------------------------------
# Intercept           1.807    8.316  0.217 0.828 -14.492 18.106
# species[T.ARTCAL]  -1.429    5.410 -0.264 0.792 -12.032  9.174
# species[T.CEAGRI]   6.016    5.222  1.152 0.249  -4.219 16.250
# species[T.ERIKAR] -12.658    5.016 -2.524 0.012 -22.489 -2.828
# species[T.HETARB]  11.932    5.969  1.999 0.046   0.234 23.630
# species[T.MALLAU]  -2.647    5.945 -0.445 0.656 -14.299  9.006
# species[T.SALAPI]   0.198    5.375  0.037 0.971 -10.336 10.732
# species[T.SALLEU]  -2.810    5.085 -0.553 0.581 -12.777  7.157
# total_branch_mass   1.146    0.360  3.181 0.001   0.440  1.852
# Group Var          38.508    2.421
# ==============================================================
#
# """

# %%
results.aic
# Out:
# 1243.0361180203022

# %% [markdown]
# # Examine Correlation & Structure in Num. Var's

# %%
cols_num_use = ['lfm', 'LMA', 'sample_wt', 'leaf_mass_ratio', 'branching', 'mpa', 'start_temp', 'dmc', 'branch_volume', 'stem_sav', 'leaf_sav', 'thickness']

corrplot(flamog, cols_num_use)

# %%
# PCAplot(flamog, cols_num_use)

# %% [markdown]
# # Modeling Preprocessing

# %%
# scale and center
cols_all = ['fh', 'fd', 'temp_change', 'heat_flux_change'] + cols_num_use
flam = scale_and_center(flamog, cols_all, cols_no_change=['plant_id', 'species', 'ignition'])

# declare as factors
flam['species'] = pd.Categorical(flam['species'])
flam['plant_id'] = pd.Categorical(flam['plant_id'])
flam['ignition'] = pd.Categorical(flam['ignition'])

# drop na's
print(len(flam))
cols_all_dpna = cols_all + ['plant_id', 'species', 'ignition']
flam.dropna(subset=cols_all_dpna, inplace=True)
print(len(flam))

# declare all possible IV cols to model
cols_use = cols_num_use + ['species']
print(cols_use)
# Out:
# 171
# 166
# ['lfm', 'LMA', 'sample_wt', 'leaf_mass_ratio', 'branching', 'mpa', 'start_temp', 'dmc', 'branch_volume', 'stem_sav', 'leaf_sav', 'thickness', 'species']

# %% [markdown]
# # Gather Info - Reduce Cols to Test

# %%
# singletons: y = b + mx
compare_predictors_mixedeff(flam, cols_num_use, yvar='fh')
# Out:
#                cols         pvals     coefs  significant
# 2         sample_wt  2.290442e-17  0.531690         True
# 9          stem_sav  8.211280e-11 -0.576347         True
# 1               LMA  1.686945e-06  0.448328         True
# 8     branch_volume  1.785638e-06  0.328704         True
# 3   leaf_mass_ratio  1.627335e-05 -0.473655         True
# 4         branching  2.782677e-05  0.276897         True
# 0               lfm  1.956642e-04 -0.386256         True
# 7               dmc  1.914826e-03  0.275048         True
# 10         leaf_sav  5.369394e-03 -0.305540         True
# 5               mpa  2.542692e-01  0.088750        False
# 6        start_temp  3.136141e-01  0.077621        False
# 11        thickness  3.205268e-01  0.115109        False

# %%
# singleton interactions: y = b + m1x1 + m2x2 + m3x1x2
sig_interactions = compare_predictors_interaction_singletons(flam,cols_use, y='fh', thresh=0.05, probs = ['fh ~ LMA*species'], printsumm=0)
# Out:
# fh ~ lfm*sample_wt
# fh ~ lfm*dmc
# fh ~ lfm*branch_volume
# fh ~ lfm*leaf_sav
# fh ~ lfm*thickness
# fh ~ lfm*species
# fh ~ LMA*stem_sav
# fh ~ sample_wt*species
# fh ~ leaf_mass_ratio*dmc
# fh ~ leaf_mass_ratio*leaf_sav
# fh ~ leaf_mass_ratio*thickness
# fh ~ leaf_mass_ratio*species
# fh ~ branching*leaf_sav
# fh ~ branching*species
# fh ~ mpa*branch_volume
# fh ~ mpa*species
# fh ~ start_temp*dmc
# fh ~ start_temp*species
# fh ~ dmc*stem_sav
# fh ~ dmc*leaf_sav
# fh ~ dmc*thickness
# fh ~ dmc*species
# fh ~ branch_volume*leaf_sav
# fh ~ branch_volume*thickness
# fh ~ branch_volume*species
# fh ~ stem_sav*species
# fh ~ leaf_sav*species
# fh ~ thickness*species
# 13 13 {'species', 'branching', 'lfm', 'leaf_mass_ratio', 'mpa', 'start_temp', 'sample_wt', 'LMA', 'leaf_sav', 'branch_volume', 'thickness', 'dmc', 'stem_sav'}

# %%
# try all 2-way interactions in 1 model
form_all_int = formula_all_2way_interactions(cols_use, y='fh', report=0)
model = smf.mixedlm(form_all_int, data=flam, groups=flam["plant_id"])
result = model.fit(reml=False)
# print only significant results
significant_results = result.summary().tables[1].loc[result.pvalues < 0.05]
print(significant_results)
# Out:
#                                 Coef. Std.Err.       z  P>|z|  [0.025  0.975]
# lfm:mpa                         0.554    0.219   2.530  0.011   0.125   0.983
# LMA:sample_wt                  -4.357    1.443  -3.019  0.003  -7.186  -1.528
# LMA:branching                  -1.785    0.485  -3.682  0.000  -2.736  -0.835
# LMA:mpa                        -1.491    0.508  -2.936  0.003  -2.486  -0.495
# LMA:start_temp                  2.153    0.534   4.035  0.000   1.107   3.199
# LMA:branch_volume               4.415    1.265   3.491  0.000   1.936   6.893
# sample_wt:leaf_mass_ratio       3.305    0.670   4.932  0.000   1.992   4.618
# sample_wt:branching            -0.564    0.197  -2.858  0.004  -0.951  -0.177
# sample_wt:dmc                   1.839    0.845   2.176  0.030   0.182   3.496
# sample_wt:branch_volume         0.410    0.121   3.384  0.001   0.172   0.647
# sample_wt:stem_sav             11.731    2.845   4.124  0.000   6.155  17.307
# sample_wt:leaf_sav              7.777    1.495   5.201  0.000   4.846  10.708
# sample_wt:thickness             6.043    1.134   5.330  0.000   3.821   8.265
# leaf_mass_ratio:branching      -1.459    0.220  -6.639  0.000  -1.890  -1.029
# leaf_mass_ratio:mpa             1.461    0.232   6.298  0.000   1.007   1.916
# leaf_mass_ratio:branch_volume  -2.918    0.457  -6.381  0.000  -3.815  -2.022
# branching:start_temp            0.597    0.115   5.198  0.000   0.372   0.822
# branching:dmc                  -0.983    0.249  -3.954  0.000  -1.471  -0.496
# mpa:dmc                         1.448    0.226   6.405  0.000   1.005   1.891
# mpa:branch_volume               0.521    0.233   2.232  0.026   0.063   0.978
# mpa:stem_sav                    1.257    0.380   3.313  0.001   0.514   2.001
# mpa:thickness                   0.876    0.209   4.192  0.000   0.466   1.286
# start_temp:stem_sav             1.546    0.464   3.331  0.001   0.636   2.455
# dmc:branch_volume               1.727    0.606   2.851  0.004   0.540   2.915
# branch_volume:stem_sav          7.352    1.984   3.706  0.000   3.463  11.240
# branch_volume:leaf_sav         -4.023    1.132  -3.555  0.000  -6.242  -1.805
# branch_volume:thickness        -2.587    0.734  -3.526  0.000  -4.025  -1.149

# %% [markdown]
# # Run Model Selector
#
# ### NOTE: Random effect is simply `plant_id`
# - NO nested effects
# - NO `species'
#
# #### It was not possible to test all combinations. Therefore, only combinations of significnt interaction terms and all singletons will be tested.

# %%
# generate list of known interactions

sig_interactions_tuples = [tuple(x.split('*')) for x in sig_interactions]
print(len(sig_interactions_tuples))
sig_interactions_tuples_red = sig_interactions_tuples[27:]
sig_interactions_tuples_red
# Out:
# 28
# [('thickness', 'species')]

# %%
# generate list of formulas

df = flam
cols = cols_use
int_tuple_list = sig_interactions_tuples
dv = 'fh'
maxnumsingle = 3
minnumsingle = 1


formulas = []
cols_used = []

# iterate over possible interactions
for int_tup in sig_interactions_tuples_red:
    
    # create a copy of singletons list
    cols_wkg = cols.copy()
    # isolate terms in interaction
    x1,x2 = int_tup
    # drop those terms from singletons list
    cols_wkg.remove(x1)
    cols_wkg.remove(x2)
    
    # add the 1st formula - just the interaction term y ~ x1 * x2
    formulas.append(dv+' ~ '+x1+'*'+x2)
    colsi = [x1,x2]

    # generate list of all possible combos of singletons, from 1 to as many as there are
    singles_combos = [list(combinations(cols_wkg, n)) for n in range(minnumsingle, maxnumsingle+1)]

    # iterate over combo set (ie 1 poss singleton, 2 poss singletons, ... etc)
    for comboset in singles_combos:
        # for each combo in the combo set
        for combo in comboset:
            # generate formula
            form = dv+' ~ '+x1+'*'+x2
            for single in combo:
                form+=' + '+single
                colsi.append(single)
            formulas.append(form)
            cols_used.append([colsi])

print(len(formulas))
# Out:
# 232

# %%
# AIC ITERATION

form_cols = cols_used

# drop non-converging formulas
problems = [
    'fh ~ thickness*species + branch_volume + stem_sav + leaf_sav'
]
for probi in problems:
    if probi in formulas:
        formulas.remove(probi)

# evaluate all models using AIC, present top models
resdf, num_top_models = AICscore_from_all_pos_2way_interactions(df, formulas, form_cols, report=1)

for idx,row in resdf[0:num_top_models].iterrows():
    formula = row.Formula
    cols = row.form_cols
    model = smf.ols(formula, data=df)
    results = model.fit()
    print(results.summary())
    plot_ols_coefficients(results)
    if 'species' in cols:
        cols.remove('species')
    plot_resid(df, cols, results)
# Out:
# fh ~ thickness*species
# fh ~ thickness*species + lfm
# fh ~ thickness*species + LMA
# fh ~ thickness*species + sample_wt
# fh ~ thickness*species + leaf_mass_ratio
# fh ~ thickness*species + branching
# fh ~ thickness*species + mpa
# fh ~ thickness*species + start_temp
# fh ~ thickness*species + dmc
# fh ~ thickness*species + branch_volume
# fh ~ thickness*species + stem_sav
# fh ~ thickness*species + leaf_sav
# fh ~ thickness*species + lfm + LMA
# fh ~ thickness*species + lfm + sample_wt
# fh ~ thickness*species + lfm + leaf_mass_ratio
# fh ~ thickness*species + lfm + branching
# fh ~ thickness*species + lfm + mpa
# fh ~ thickness*species + lfm + start_temp
# fh ~ thickness*species + lfm + dmc
# fh ~ thickness*species + lfm + branch_volume
# fh ~ thickness*species + lfm + stem_sav
# fh ~ thickness*species + lfm + leaf_sav
# fh ~ thickness*species + LMA + sample_wt
# fh ~ thickness*species + LMA + leaf_mass_ratio
# fh ~ thickness*species + LMA + branching
# fh ~ thickness*species + LMA + mpa
# fh ~ thickness*species + LMA + start_temp
# fh ~ thickness*species + LMA + dmc
# fh ~ thickness*species + LMA + branch_volume
# fh ~ thickness*species + LMA + stem_sav
# fh ~ thickness*species + LMA + leaf_sav
# fh ~ thickness*species + sample_wt + leaf_mass_ratio
# fh ~ thickness*species + sample_wt + branching
# fh ~ thickness*species + sample_wt + mpa
# fh ~ thickness*species + sample_wt + start_temp
# fh ~ thickness*species + sample_wt + dmc
# fh ~ thickness*species + sample_wt + branch_volume
# fh ~ thickness*species + sample_wt + stem_sav
# fh ~ thickness*species + sample_wt + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + branching
# fh ~ thickness*species + leaf_mass_ratio + mpa
# fh ~ thickness*species + leaf_mass_ratio + start_temp
# fh ~ thickness*species + leaf_mass_ratio + dmc
# fh ~ thickness*species + leaf_mass_ratio + branch_volume
# fh ~ thickness*species + leaf_mass_ratio + stem_sav
# fh ~ thickness*species + leaf_mass_ratio + leaf_sav
# fh ~ thickness*species + branching + mpa
# fh ~ thickness*species + branching + start_temp
# fh ~ thickness*species + branching + dmc
# fh ~ thickness*species + branching + branch_volume
# fh ~ thickness*species + branching + stem_sav
# fh ~ thickness*species + branching + leaf_sav
# fh ~ thickness*species + mpa + start_temp
# fh ~ thickness*species + mpa + dmc
# fh ~ thickness*species + mpa + branch_volume
# fh ~ thickness*species + mpa + stem_sav
# fh ~ thickness*species + mpa + leaf_sav
# fh ~ thickness*species + start_temp + dmc
# fh ~ thickness*species + start_temp + branch_volume
# fh ~ thickness*species + start_temp + stem_sav
# fh ~ thickness*species + start_temp + leaf_sav
# fh ~ thickness*species + dmc + branch_volume
# fh ~ thickness*species + dmc + stem_sav
# fh ~ thickness*species + dmc + leaf_sav
# fh ~ thickness*species + branch_volume + stem_sav
# fh ~ thickness*species + branch_volume + leaf_sav
# fh ~ thickness*species + stem_sav + leaf_sav
# fh ~ thickness*species + lfm + LMA + sample_wt
# fh ~ thickness*species + lfm + LMA + leaf_mass_ratio
# fh ~ thickness*species + lfm + LMA + branching
# fh ~ thickness*species + lfm + LMA + mpa
# fh ~ thickness*species + lfm + LMA + start_temp
# fh ~ thickness*species + lfm + LMA + dmc
# fh ~ thickness*species + lfm + LMA + branch_volume
# fh ~ thickness*species + lfm + LMA + stem_sav
# fh ~ thickness*species + lfm + LMA + leaf_sav
# fh ~ thickness*species + lfm + sample_wt + leaf_mass_ratio
# fh ~ thickness*species + lfm + sample_wt + branching
# fh ~ thickness*species + lfm + sample_wt + mpa
# fh ~ thickness*species + lfm + sample_wt + start_temp
# fh ~ thickness*species + lfm + sample_wt + dmc
# fh ~ thickness*species + lfm + sample_wt + branch_volume
# fh ~ thickness*species + lfm + sample_wt + stem_sav
# fh ~ thickness*species + lfm + sample_wt + leaf_sav
# fh ~ thickness*species + lfm + leaf_mass_ratio + branching
# fh ~ thickness*species + lfm + leaf_mass_ratio + mpa
# fh ~ thickness*species + lfm + leaf_mass_ratio + start_temp
# fh ~ thickness*species + lfm + leaf_mass_ratio + dmc
# fh ~ thickness*species + lfm + leaf_mass_ratio + branch_volume
# fh ~ thickness*species + lfm + leaf_mass_ratio + stem_sav
# fh ~ thickness*species + lfm + leaf_mass_ratio + leaf_sav
# fh ~ thickness*species + lfm + branching + mpa
# fh ~ thickness*species + lfm + branching + start_temp
# fh ~ thickness*species + lfm + branching + dmc
# fh ~ thickness*species + lfm + branching + branch_volume
# fh ~ thickness*species + lfm + branching + stem_sav
# fh ~ thickness*species + lfm + branching + leaf_sav
# fh ~ thickness*species + lfm + mpa + start_temp
# fh ~ thickness*species + lfm + mpa + dmc
# fh ~ thickness*species + lfm + mpa + branch_volume
# fh ~ thickness*species + lfm + mpa + stem_sav
# fh ~ thickness*species + lfm + mpa + leaf_sav
# fh ~ thickness*species + lfm + start_temp + dmc
# fh ~ thickness*species + lfm + start_temp + branch_volume
# fh ~ thickness*species + lfm + start_temp + stem_sav
# fh ~ thickness*species + lfm + start_temp + leaf_sav
# fh ~ thickness*species + lfm + dmc + branch_volume
# fh ~ thickness*species + lfm + dmc + stem_sav
# fh ~ thickness*species + lfm + dmc + leaf_sav
# fh ~ thickness*species + lfm + branch_volume + stem_sav
# fh ~ thickness*species + lfm + branch_volume + leaf_sav
# fh ~ thickness*species + lfm + stem_sav + leaf_sav
# fh ~ thickness*species + LMA + sample_wt + leaf_mass_ratio
# fh ~ thickness*species + LMA + sample_wt + branching
# fh ~ thickness*species + LMA + sample_wt + mpa
# fh ~ thickness*species + LMA + sample_wt + start_temp
# fh ~ thickness*species + LMA + sample_wt + dmc
# fh ~ thickness*species + LMA + sample_wt + branch_volume
# fh ~ thickness*species + LMA + sample_wt + stem_sav
# fh ~ thickness*species + LMA + sample_wt + leaf_sav
# fh ~ thickness*species + LMA + leaf_mass_ratio + branching
# fh ~ thickness*species + LMA + leaf_mass_ratio + mpa
# fh ~ thickness*species + LMA + leaf_mass_ratio + start_temp
# fh ~ thickness*species + LMA + leaf_mass_ratio + dmc
# fh ~ thickness*species + LMA + leaf_mass_ratio + branch_volume
# fh ~ thickness*species + LMA + leaf_mass_ratio + stem_sav
# fh ~ thickness*species + LMA + leaf_mass_ratio + leaf_sav
# fh ~ thickness*species + LMA + branching + mpa
# fh ~ thickness*species + LMA + branching + start_temp
# fh ~ thickness*species + LMA + branching + dmc
# fh ~ thickness*species + LMA + branching + branch_volume
# fh ~ thickness*species + LMA + branching + stem_sav
# fh ~ thickness*species + LMA + branching + leaf_sav
# fh ~ thickness*species + LMA + mpa + start_temp
# fh ~ thickness*species + LMA + mpa + dmc
# fh ~ thickness*species + LMA + mpa + branch_volume
# fh ~ thickness*species + LMA + mpa + stem_sav
# fh ~ thickness*species + LMA + mpa + leaf_sav
# fh ~ thickness*species + LMA + start_temp + dmc
# fh ~ thickness*species + LMA + start_temp + branch_volume
# fh ~ thickness*species + LMA + start_temp + stem_sav
# fh ~ thickness*species + LMA + start_temp + leaf_sav
# fh ~ thickness*species + LMA + dmc + branch_volume
# fh ~ thickness*species + LMA + dmc + stem_sav
# fh ~ thickness*species + LMA + dmc + leaf_sav
# fh ~ thickness*species + LMA + branch_volume + stem_sav
# fh ~ thickness*species + LMA + branch_volume + leaf_sav
# fh ~ thickness*species + LMA + stem_sav + leaf_sav
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + branching
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + mpa
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + start_temp
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + dmc
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + branch_volume
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + stem_sav
# fh ~ thickness*species + sample_wt + leaf_mass_ratio + leaf_sav
# fh ~ thickness*species + sample_wt + branching + mpa
# fh ~ thickness*species + sample_wt + branching + start_temp
# fh ~ thickness*species + sample_wt + branching + dmc
# fh ~ thickness*species + sample_wt + branching + branch_volume
# fh ~ thickness*species + sample_wt + branching + stem_sav
# fh ~ thickness*species + sample_wt + branching + leaf_sav
# fh ~ thickness*species + sample_wt + mpa + start_temp
# fh ~ thickness*species + sample_wt + mpa + dmc
# fh ~ thickness*species + sample_wt + mpa + branch_volume
# fh ~ thickness*species + sample_wt + mpa + stem_sav
# fh ~ thickness*species + sample_wt + mpa + leaf_sav
# fh ~ thickness*species + sample_wt + start_temp + dmc
# fh ~ thickness*species + sample_wt + start_temp + branch_volume
# fh ~ thickness*species + sample_wt + start_temp + stem_sav
# fh ~ thickness*species + sample_wt + start_temp + leaf_sav
# fh ~ thickness*species + sample_wt + dmc + branch_volume
# fh ~ thickness*species + sample_wt + dmc + stem_sav
# fh ~ thickness*species + sample_wt + dmc + leaf_sav
# fh ~ thickness*species + sample_wt + branch_volume + stem_sav
# fh ~ thickness*species + sample_wt + branch_volume + leaf_sav
# fh ~ thickness*species + sample_wt + stem_sav + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + branching + mpa
# fh ~ thickness*species + leaf_mass_ratio + branching + start_temp
# fh ~ thickness*species + leaf_mass_ratio + branching + dmc
# fh ~ thickness*species + leaf_mass_ratio + branching + branch_volume
# fh ~ thickness*species + leaf_mass_ratio + branching + stem_sav
# fh ~ thickness*species + leaf_mass_ratio + branching + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + mpa + start_temp
# fh ~ thickness*species + leaf_mass_ratio + mpa + dmc
# fh ~ thickness*species + leaf_mass_ratio + mpa + branch_volume
# fh ~ thickness*species + leaf_mass_ratio + mpa + stem_sav
# fh ~ thickness*species + leaf_mass_ratio + mpa + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + start_temp + dmc
# fh ~ thickness*species + leaf_mass_ratio + start_temp + branch_volume
# fh ~ thickness*species + leaf_mass_ratio + start_temp + stem_sav
# fh ~ thickness*species + leaf_mass_ratio + start_temp + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + dmc + branch_volume
# fh ~ thickness*species + leaf_mass_ratio + dmc + stem_sav
# fh ~ thickness*species + leaf_mass_ratio + dmc + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + branch_volume + stem_sav
# fh ~ thickness*species + leaf_mass_ratio + branch_volume + leaf_sav
# fh ~ thickness*species + leaf_mass_ratio + stem_sav + leaf_sav
# fh ~ thickness*species + branching + mpa + start_temp
# fh ~ thickness*species + branching + mpa + dmc
# fh ~ thickness*species + branching + mpa + branch_volume
# fh ~ thickness*species + branching + mpa + stem_sav
# fh ~ thickness*species + branching + mpa + leaf_sav
# fh ~ thickness*species + branching + start_temp + dmc
# fh ~ thickness*species + branching + start_temp + branch_volume
# fh ~ thickness*species + branching + start_temp + stem_sav
# fh ~ thickness*species + branching + start_temp + leaf_sav
# fh ~ thickness*species + branching + dmc + branch_volume
# fh ~ thickness*species + branching + dmc + stem_sav
# fh ~ thickness*species + branching + dmc + leaf_sav
# fh ~ thickness*species + branching + branch_volume + stem_sav
# fh ~ thickness*species + branching + branch_volume + leaf_sav
# fh ~ thickness*species + branching + stem_sav + leaf_sav
# fh ~ thickness*species + mpa + start_temp + dmc
# fh ~ thickness*species + mpa + start_temp + branch_volume
# fh ~ thickness*species + mpa + start_temp + stem_sav
# fh ~ thickness*species + mpa + start_temp + leaf_sav
# fh ~ thickness*species + mpa + dmc + branch_volume
# fh ~ thickness*species + mpa + dmc + stem_sav
# fh ~ thickness*species + mpa + dmc + leaf_sav
# fh ~ thickness*species + mpa + branch_volume + stem_sav
# fh ~ thickness*species + mpa + branch_volume + leaf_sav
# fh ~ thickness*species + mpa + stem_sav + leaf_sav
# fh ~ thickness*species + start_temp + dmc + branch_volume
# fh ~ thickness*species + start_temp + dmc + stem_sav
# fh ~ thickness*species + start_temp + dmc + leaf_sav
# fh ~ thickness*species + start_temp + branch_volume + stem_sav
# fh ~ thickness*species + start_temp + branch_volume + leaf_sav
# fh ~ thickness*species + start_temp + stem_sav + leaf_sav
# fh ~ thickness*species + dmc + branch_volume + stem_sav
# fh ~ thickness*species + dmc + branch_volume + leaf_sav
# fh ~ thickness*species + dmc + stem_sav + leaf_sav
# 321.5 :  fh ~ thickness*species + sample_wt + branching + start_temp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     fh   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.633
# Method:                 Least Squares   F-statistic:                     16.83
# Date:                Tue, 23 Apr 2024   Prob (F-statistic):           2.98e-27
# Time:                        12:17:43   Log-Likelihood:                -139.75
# No. Observations:                 166   AIC:                             317.5
# Df Residuals:                     147   BIC:                             376.6
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.5842      0.480      1.217      0.226      -0.365       1.533
# species[T.ARTCAL]              -0.6624      0.810     -0.818      0.415      -2.264       0.939
# species[T.CEAGRI]              -0.1786      0.501     -0.357      0.722      -1.168       0.811
# species[T.ERIKAR]              -1.5128      0.580     -2.606      0.010      -2.660      -0.366
# species[T.HETARB]              -0.8308      0.679     -1.224      0.223      -2.172       0.510
# species[T.MALLAU]               0.1083      0.643      0.168      0.867      -1.163       1.380
# species[T.SALAPI]              -0.1648      0.510     -0.323      0.747      -1.173       0.844
# species[T.SALLEU]              -0.5098      0.494     -1.033      0.303      -1.485       0.466
# thickness                      -0.7240      0.455     -1.591      0.114      -1.623       0.175
# thickness:species[T.ARTCAL]     0.7223      0.853      0.847      0.399      -0.963       2.408
# thickness:species[T.CEAGRI]     0.9480      0.528      1.795      0.075      -0.096       1.992
# thickness:species[T.ERIKAR]     0.3423      0.619      0.553      0.581      -0.882       1.566
# thickness:species[T.HETARB]     3.7338      1.359      2.747      0.007       1.047       6.420
# thickness:species[T.MALLAU]     2.5509      1.131      2.255      0.026       0.316       4.786
# thickness:species[T.SALAPI]     0.6177      0.518      1.193      0.235      -0.405       1.641
# thickness:species[T.SALLEU]     0.7134      0.461      1.546      0.124      -0.199       1.625
# sample_wt                       0.4485      0.082      5.463      0.000       0.286       0.611
# branching                       0.1917      0.066      2.900      0.004       0.061       0.322
# start_temp                      0.1801      0.072      2.515      0.013       0.039       0.322
# ==============================================================================
# Omnibus:                        7.696   Durbin-Watson:                   1.827
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):               13.969
# Skew:                           0.079   Prob(JB):                     0.000926
# Kurtosis:                       4.412   Cond. No.                         59.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 23
#      21 print(results.summary())
#      22 plot_ols_coefficients(results)
# ---> 23 cols.remove('species')
#      24 plot_resid(df, cols, results)
#
# ValueError: list.remove(x): x not in list

# %%
print('done')
